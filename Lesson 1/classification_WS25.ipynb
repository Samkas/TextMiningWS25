# %% [markdown]
# ### Loading our data
#
# For the following exercise we will use the word count matrix representation and only use a small subset of our data to increase computational speed

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from nltk.corpus import stopwords as nltkStopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
import numpy as np
import itertools
from collections import Counter

classes_en = {1: "World", 2: "Sports", 3: "Business", 4: "Sci/Tech"}
data_en = pd.read_csv("../data/AGNews/train.csv", 
                       names = ["Label", "Title", "Article"],
                       encoding = "utf-8")

# test_en = pd.read_csv("../data/AGNews/test.csv", 
#                       names = ["Label", "Title", "Article"],
#                       encoding = "utf-8")

sample = data_en.sample(200)

# %% [markdown]
# ### Splitting data into a training dataset and a test dataset
#
# *Note:* Data splitting should be your first step in any data science project that involves some kind of machine learning, doing transformations - even something like word counts - will inherently introduce bias and make the calculated generalization error on the test datast less meaningful!

# %%
# we are reserving 35% of the sample for testing
train, test = train_test_split(sample, test_size = 0.35, random_state = 1337)
print(train.shape)
print(test.shape)
train.head()
# Out:
# (130, 3)
# (70, 3)
#        Label                                 Title  \
# 92480      3        Many in county due tax refunds
# 92795      1              Rebels attacked in Mosul
# 612        1  Election-Year Rate Hike Puzzles Some
# 86936      2                     Robson Leads Kanu
# 17066      4  Service pack 2: It #39;s in the mail
#
#                                                  Article
# 92480  The tax man is trying to give away more than \...
# 92795  THE British-Iraqi aid executive Margaret Hassa...
# 612    WASHINGTON - Going against conventional wisdom...
# 86936  Super Eagles Nwankwo Kanu #39;s West Bromwich ...
# 17066  Japanese consumers will be spared the agony of...

# %% [markdown]
# ### Creating the word count matrices
#
# Notice that we will not fit_transform the test data but apply the same transformation that we use for the training data.

# %%
# separate the labels and documents
labels_train = [classes_en[int(row["Label"])] for i, row in train.iterrows()]
docs_train = [row["Article"] for i, row in train.iterrows()]

labels_test = [classes_en[int(row["Label"])] for i, row in test.iterrows()]
docs_test = [row["Article"] for i, row in test.iterrows()]

# print some info
print(f"Training labels: {labels_train[:2]}")
print(f"Training documens: {docs_train[:2]}")

# get the stopwords and create the count vectorizer
stopwords_en = list(nltkStopwords.words("english"))
count_vectorizer = CountVectorizer(strip_accents = "unicode",
                                   stop_words = stopwords_en)

# fit_transform the training data and transform the test data
X_train = count_vectorizer.fit_transform(docs_train)
X_test = count_vectorizer.transform(docs_test)

# get the feature names and print the shapes
counts_features_names = count_vectorizer.get_feature_names_out()
print(X_train.shape)
print(X_test.shape)
print(counts_features_names.shape)

# convert to dataframes for easier handling
counts_train = pd.DataFrame(X_train.toarray(), columns = counts_features_names)
counts_train["Label"] = labels_train

counts_test = pd.DataFrame(X_test.toarray(), columns = counts_features_names)
counts_test["Label"] = labels_test
# Out:
# Training labels: ['Business', 'World']
# Training documens: ['The tax man is trying to give away more than \\$220,000 in San Mateo County -- and some of it might be yours. More than 230 county residents have not collected their federal ', 'THE British-Iraqi aid executive Margaret Hassan, kidnapped by rebels in Iraq, was feared dead today, as US-led forces swept into the flashpoint city of Mosul in a renewed offensive against insurgents.']
# (130, 1729)
# (70, 1729)
# (1729,)

# %% [markdown]
# You can use this function to plot a confusion matrices of the predictions

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title="Confusion matrix", cmap=plt.cm.Blues):
    # display the confusion matrix as an image
    plt.imshow(cm, interpolation="nearest", cmap=cmap)
    plt.title(title)
    plt.colorbar()

    # set tick marks and labels for x and y axes
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    # normalize the confusion matrix if requested
    if normalize:
        cm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")

    # set threshold for text color contrast
    thresh = cm.max() / 2.

    # annotate each cell with its value
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], ".2f") if normalize else int(cm[i, j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    # adjust layout and axis labels
    plt.tight_layout()
    plt.ylim(len(cm) - 0.5, -0.5)  # fix for matplotlib's y-axis inversion
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# ## Classification
#
# **Exercise**: Using sklearn as your basis, do the following:
#
# Example classifiers: NaiveBayes, RandomForestClassifier, LogisticRegression, KNeighborsClassifiers, LinearSVC,
#
# * take two models of your choosing from sklearn and classify the computed features
# * Compute the accuracy of each classifier
# * Compare their results: which worked best? what are their differences?
# * Visualize them with a confusion matrix
# * What is their accuracy in training and test?
#
# Once this is done do the following
#
# Run the classifiers again on the "cleaned" dataset from the clustering exercise. For example, import the cleaning function from `clean.py` and apply it to training and test partition with the code below:
#
# ```python
# from clean import clean
#
# docs_cleaned_train = [clean(row["Article"]) for i, row in train.iterrows()]
# docs_cleaned_test = [clean(row["Article"]) for i, row in test.iterrows()]
# ```
#
# Compare the performance between the "cleaned" and "not cleaned" datasets, which one performs better?

# %% [markdown]
# Evaluating the implementation on our training data

# %%
from sklearn.naive_bayes import GaussianNB

# ? your code here

# %%
# plotting the confusion matrix

# ? your code here

# %%
# for a proper evaluation of the performance, lets compute the accuracy

# ? your code here
# Out:
# Train Accuracy:  1.0

# %% [markdown]
#  repeating the same for the test data

# %%
# ? your code here

# %% [markdown]
# Same for the cleaned data

# %%
# ? your code here

# %% [markdown]
# ### **Bonus Exercise:** Implement the kNN algorithm using the TF-IDF matrix representation and using the cosine distance!
#
# Compare (the performance of) your solution to that of the kNN implementation of sklearn: [https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)

# %%
# ? your code here
